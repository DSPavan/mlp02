# %%
# Data Manupulation
import numpy as np
import pandas as pd
# Plotting graphs
import matplotlib.pyplot as plt
# CSV File - Read
df = pd.read_csv('C:\\Users\\radha\\Desktop\\dsp27 Class\\cerealspga05.csv')
#  ,header=None ,skiprows=1 , names=['Cal', 'Pr', 'Fat', 'sod', 'Fib', 'Rting']
print(df.head(2))
# Out:
#         name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 0  100%_Bran   N    C        70        4    1     130   10.0    5.0       6
# 1   All-Bran   K    C        70        4    1     260    9.0    7.0       5
#
#    potass  vitamins  shelf  weight  cups     rating
# 0     280        25      3     1.0  0.33  68.402973
# 1     320        25      3     1.0  0.33  59.425505

# %%
dfnew = df[['calories','fat','fiber','sugars']]
# with and without rating

# %%
#Finding the optimum number of clusters for k-means classification - ELBOW METHOD
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(dfnew)
    wcss.append(kmeans.inertia_)
    
#Plotting the results onto a line graph, allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
# cluster 4 or 8 
kmeans = KMeans(n_clusters=4)

kmeans.fit(dfnew)
y_kmeans = kmeans.predict(dfnew)

# %%
y_kmeans
# Out:
# array([2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 1, 0, 0, 3, 3, 3, 3, 3, 3, 0, 3, 3,
#        0, 3, 0, 0, 3, 3, 0, 3, 3, 0, 3, 0, 3, 3, 3, 3, 3, 3, 1, 3, 0, 3,
#        0, 1, 0, 3, 1, 0, 1, 0, 2, 2, 0, 0, 0, 0, 3, 3, 0, 0, 0, 3, 3, 0,
#        3, 1, 0, 3, 3, 0, 0, 3])

# %%
#dfnew.head()
df3 = dfnew.assign(clusterNo = y_kmeans, namex = df['name'])
print(df3.head())
# Out:
#    calories  fat  fiber  sugars  clusterNo                      namex
# 0        70    1   10.0       6          2                  100%_Bran
# 1        70    1    9.0       5          2                   All-Bran
# 2        50    0   14.0       0          2  All-Bran_with_Extra_Fiber
# 3       110    3    4.0       7          3         Cracklin'_Oat_Bran
# 4       120    1    6.0      14          3      Post_Nat._Raisin_Bran

# %%
from pandasql import sqldf
print(sqldf("select namex,clusterno,calories from df3 order by clusterno"))
# Out:
#                      namex  clusterNo  calories
# 0                Bran_Chex          0        90
# 1              Bran_Flakes          0        90
# 2              Corn_Flakes          0       100
# 3   Cream_of_Wheat_(Quick)          0       100
# 4   Crispy_Wheat_&_Raisins          0       100
# ..                     ...        ...       ...
# 69               Special_K          3       110
# 70       Total_Corn_Flakes          3       110
# 71                 Triples          3       110
# 72                    Trix          3       110
# 73     Wheaties_Honey_Gold          3       110
#
# [74 rows x 3 columns]

# %%
print(sqldf("select namex,clusterno,calories from df3 where clusterno=3"))
# Out:
#                           namex  clusterNo  calories
# 0            Cracklin'_Oat_Bran          3       110
# 1         Post_Nat._Raisin_Bran          3       120
# 2                   Raisin_Bran          3       120
# 3             100%_Natural_Bran          3       120
# 4                Almond_Delight          3       110
# 5       Apple_Cinnamon_Cheerios          3       110
# 6                   Apple_Jacks          3       110
# 7                  Cap'n'Crunch          3       120
# 8                      Cheerios          3       110
# 9         Cinnamon_Toast_Crunch          3       120
# 10                     Clusters          3       110
# 11                  Cocoa_Puffs          3       110
# 12                    Corn_Chex          3       110
# 13                    Corn_Pops          3       110
# 14                Count_Chocula          3       110
# 15                      Crispix          3       110
# 16                  Froot_Loops          3       110
# 17               Frosted_Flakes          3       110
# 18                Fruitful_Bran          3       120
# 19               Fruity_Pebbles          3       110
# 20               Golden_Grahams          3       110
# 21                   Grape-Nuts          3       110
# 22           Great_Grains_Pecan          3       120
# 23             Honey_Graham_Ohs          3       120
# 24           Honey_Nut_Cheerios          3       110
# 25                   Honey-comb          3       110
# 26  Just_Right_Crunchy__Nuggets          3       110
# 27                          Kix          3       110
# 28                 Lucky_Charms          3       110
# 29             Nut&Honey_Crunch          3       120
# 30                    Rice_Chex          3       110
# 31                Rice_Krispies          3       110
# 32                       Smacks          3       110
# 33                    Special_K          3       110
# 34            Total_Corn_Flakes          3       110
# 35                      Triples          3       110
# 36                         Trix          3       110
# 37          Wheaties_Honey_Gold          3       110

# %%
# OTHER TECH: HIERACHICAL DENDROGRAM

# %% [markdown]
# ![dendro.JPG](attachment:dendro.JPG)

# %%
# OTHER TECH: HIERACHICAL DENDROGRAM
from scipy.cluster.hierarchy import dendrogram, linkage  
from matplotlib import pyplot as plt

#df = df.set_index('name')
#del df.index.name
linked = linkage(dfnew, 'single')
#linked
#print(type(linked))
plt.figure(figsize=(15, 15))  
zx = dendrogram(linked, orientation='left',labels=df.index, color_threshold=60, above_threshold_color='red')
plt.show()

# index Number at Leaf
#df = df.set_index('name')
#del df.index.name

# %%
#zx
# ICORD, DCORD, ivl, leaves, color_list, leaves_color_list'
#zx[color_list] 
#type(zx)  # dict
#zx['leaves_color_list']

# %%
#linked  # -- Explain

# The linkage matrix LINKED represents a dendrogram

#A  by 4 matrix Z is returned. 
#At the -th iteration, clusters with indices Z[i, 0] and Z[i, 1] are combined to form cluster .
#A cluster with an index less than  corresponds to one of the  original observations. 
#The distance between clusters Z[i, 0] and Z[i, 1] is given by Z[i, 2]. 
#The fourth value Z[i, 3] represents the number of original observations in the newly formed cluster.

# %%
# Filter numpy ndarray (matrix) according to column values : Stackoverflow

# %%
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
#Z = dendrogram(linked, orientation='left',labels=df.index, color_threshold=60, above_threshold_color='red')
dendrogram(
    linked,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=12,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import matplotlib as mpl

#Scaling of data
dfnew2 = df[['calories','fat','fiber','sugars','rating']]

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x = dfnew2
xScale = ss.fit_transform(x)

#xScale


cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')  
cluster.fit_predict(xScale)
fig, ax = plt.subplots()
#x.iloc[:,0]
#print(x)
ax.scatter(x.iloc[:,0],x.iloc[:,4], c=cluster.labels_, cmap='rainbow')

# %%
# METRICS

#Elbow method
#Silhouette analysis

# %%
# Run the Kmeans algorithm and get the index of data points clusters
sse = []
list_k = list(range(1, 10))

for k in list_k:
    km = KMeans(n_clusters=k)
    km.fit(dfnew)
    sse.append(km.inertia_)

# Plot sse against k
plt.figure(figsize=(6, 6))
plt.plot(list_k, sse, '-o')
plt.xlabel(r'Number of clusters *k*')
plt.ylabel('Sum of squared distance');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Silhouette analysis can be used to determine the degree of separation between clusters. For each sample:

# %%
kmeans.fit(dfnew)
# Out:
# KMeans(n_clusters=4)

# %%
# silhouette_score
from sklearn.metrics import silhouette_score
range_n_clusters = [2,3,4,5,6,7,8,9,10]
#range_n_clusters = list (range(2,100))
for n_clusters in range_n_clusters:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(dfnew)
    centers = clusterer.cluster_centers_

    score = silhouette_score(dfnew, preds)
    print("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.5554029295170578)
# For n_clusters = 3, silhouette score is 0.5149099347068837)
# For n_clusters = 4, silhouette score is 0.5203582892347008)
# For n_clusters = 5, silhouette score is 0.5052793597370216)
# For n_clusters = 6, silhouette score is 0.5126991752107398)
# For n_clusters = 7, silhouette score is 0.5417383636995573)
# For n_clusters = 8, silhouette score is 0.560141666311264)
# For n_clusters = 9, silhouette score is 0.567976461438445)
# For n_clusters = 10, silhouette score is 0.5591630799887984)

# %%
# ‘k-means++’ : selects initial cluster centers for k-mean clustering in a smart way to speed up convergence
