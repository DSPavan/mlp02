# %%
import numpy as np
from PIL import Image
img = np.asarray(Image.open("C:\\Users\\radha\\Desktop\\dsp27 Class\\dog.4040.jpg"))

# %%
img
# In our array, dimension 0 represents pixel rows, from the top to the bottom of the image. 
#    Dimension 1 represents columns from left to right.
#    And dimension 2 represents color channels red, green, and blue, in that order.
# Out:
# array([[[195, 171, 135],
#         [218, 194, 158],
#         [239, 216, 182],
#         ...,
#         [237, 223, 186],
#         [233, 219, 180],
#         [231, 217, 178]],
#
#        [[236, 212, 174],
#         [235, 211, 175],
#         [229, 205, 169],
#         ...,
#         [247, 233, 196],
#         [241, 227, 190],
#         [237, 223, 184]],
#
#        [[221, 198, 157],
#         [230, 207, 166],
#         [242, 218, 180],
#         ...,
#         [235, 219, 183],
#         [237, 221, 185],
#         [238, 223, 184]],
#
#        ...,
#
#        [[231, 227, 218],
#         [235, 231, 222],
#         [228, 224, 215],
#         ...,
#         [138, 149,  89],
#         [128, 139,  79],
#         [121, 132,  72]],
#
#        [[231, 227, 216],
#         [235, 231, 220],
#         [228, 224, 213],
#         ...,
#         [162, 176, 115],
#         [147, 161, 100],
#         [132, 146,  84]],
#
#        [[231, 227, 216],
#         [235, 231, 220],
#         [228, 224, 213],
# ...

# %%
#img[row, column, channel]

img[0, 1, ]
# Out:
# array([218, 194, 158], dtype=uint8)

# %%
from PIL import Image
  
  
# sample.png is the name of the image
# file and assuming that it is uploaded
# in the current directory or we need
# to give the path
image = Image.open('C:\\Users\\radha\\Desktop\\dsp27 Class\\dog.4040.jpg')
  
# summarize some details about the image
print(image.format)
print(image.size)
print(image.mode)
# Out:
# JPEG
# (300, 251)
# RGB

# %%
  
# <class 'numpy.ndarray'>
print(type(img))
  
#  shape
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (251, 300, 3)

# %%
pilImage = Image.fromarray(img)
print(type(pilImage))
# Out:
# <class 'PIL.Image.Image'>

# %%
pilImage
# Out:
# <PIL.Image.Image image mode=RGB size=300x251 at 0xBEAAADE070>

# %%
import cv2
  
image = cv2.imread('C:\\Users\\radha\\Desktop\\dsp27 Class\\dog.4040.jpg')

# %%
# BGR -> RGB
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  
img2 = cv2.imwrite('opncv_sample.png', img) 
print (type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
image2 = cv2.imread('opncv_sample.png')
pilImage2 = Image.fromarray(image2)
pilImage2
# Out:
# <PIL.Image.Image image mode=RGB size=300x251 at 0xBEAA00FA90>
