# %% [markdown]
# ![kmeans2.JPG](attachment:kmeans2.JPG)

# %%
#Silhouette

# %% [markdown]
# ![silhou.JPG](attachment:silhou.JPG)

# %%
## KNN

# %% [markdown]
# ![KNN3.png](attachment:KNN3.png)

# %%
# KNN

# %% [markdown]
# ![KNn4.jpg](attachment:KNn4.jpg)

# %%
# KNN

# %% [markdown]
# ![knn5.JPG](attachment:knn5.JPG)
